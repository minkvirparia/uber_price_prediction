# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('uber.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                            key  fare_amount  \
# 0    24238194    2015-05-07 19:52:06.0000003          7.5
# 1    27835199    2009-07-17 20:04:56.0000002          7.7
# 2    44984355   2009-08-24 21:45:00.00000061         12.9
# 3    25894730    2009-06-26 08:22:21.0000001          5.3
# 4    17610152  2014-08-28 17:47:00.000000188         16.0
#
#            pickup_datetime  pickup_longitude  pickup_latitude  \
# 0  2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1  2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2  2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3  2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4  2014-08-28 17:47:00 UTC        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count
# 0         -73.999512         40.723217                1
# 1         -73.994710         40.750325                1
# 2         -73.962565         40.772647                1
# ...

# %%
df.drop(columns = 'Unnamed: 0', axis = 1, inplace = True)

# %%
df.head()
# Out:
#                              key  fare_amount          pickup_datetime  \
# 0    2015-05-07 19:52:06.0000003          7.5  2015-05-07 19:52:06 UTC
# 1    2009-07-17 20:04:56.0000002          7.7  2009-07-17 20:04:56 UTC
# 2   2009-08-24 21:45:00.00000061         12.9  2009-08-24 21:45:00 UTC
# 3    2009-06-26 08:22:21.0000001          5.3  2009-06-26 08:22:21 UTC
# 4  2014-08-28 17:47:00.000000188         16.0  2014-08-28 17:47:00 UTC
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.999817        40.738354         -73.999512         40.723217
# 1        -73.994355        40.728225         -73.994710         40.750325
# 2        -74.005043        40.740770         -73.962565         40.772647
# 3        -73.976124        40.790844         -73.965316         40.803349
# 4        -73.925023        40.744085         -73.973082         40.761247
#
#    passenger_count
# 0                1
# 1                1
# 2                1
# ...

# %%
df.shape
# Out:
# (200000, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   key                200000 non-null  object
#  1   fare_amount        200000 non-null  float64
#  2   pickup_datetime    200000 non-null  object
#  3   pickup_longitude   200000 non-null  float64
#  4   pickup_latitude    200000 non-null  float64
#  5   dropoff_longitude  199999 non-null  float64
#  6   dropoff_latitude   199999 non-null  float64
#  7   passenger_count    200000 non-null  int64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 12.2+ MB

# %%
df.describe()
# Out:
#          fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# count  200000.000000     200000.000000    200000.000000      199999.000000
# mean       11.359955        -72.527638        39.935885         -72.525292
# std         9.901776         11.437787         7.720539          13.117408
# min       -52.000000      -1340.648410       -74.015515       -3356.666300
# 25%         6.000000        -73.992065        40.734796         -73.991407
# 50%         8.500000        -73.981823        40.752592         -73.980093
# 75%        12.500000        -73.967154        40.767158         -73.963658
# max       499.000000         57.418457      1644.421482        1153.572603
#
#        dropoff_latitude  passenger_count
# count     199999.000000    200000.000000
# mean          39.923890         1.684535
# std            6.794829         1.385997
# min         -881.985513         0.000000
# 25%           40.733823         1.000000
# 50%           40.753042         1.000000
# ...

# %%
df.isnull().sum()
# Out:
# key                  0
# fare_amount          0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    1
# dropoff_latitude     1
# passenger_count      0
# dtype: int64

# %%
df1 = df.dropna()

# %%
df1.isnull().sum()
# Out:
# key                  0
# fare_amount          0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    0
# dropoff_latitude     0
# passenger_count      0
# dtype: int64

# %%
df1.shape
# Out:
# (199999, 8)

# %%
df1.head()
# Out:
#                              key  fare_amount          pickup_datetime  \
# 0    2015-05-07 19:52:06.0000003          7.5  2015-05-07 19:52:06 UTC
# 1    2009-07-17 20:04:56.0000002          7.7  2009-07-17 20:04:56 UTC
# 2   2009-08-24 21:45:00.00000061         12.9  2009-08-24 21:45:00 UTC
# 3    2009-06-26 08:22:21.0000001          5.3  2009-06-26 08:22:21 UTC
# 4  2014-08-28 17:47:00.000000188         16.0  2014-08-28 17:47:00 UTC
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.999817        40.738354         -73.999512         40.723217
# 1        -73.994355        40.728225         -73.994710         40.750325
# 2        -74.005043        40.740770         -73.962565         40.772647
# 3        -73.976124        40.790844         -73.965316         40.803349
# 4        -73.925023        40.744085         -73.973082         40.761247
#
#    passenger_count
# 0                1
# 1                1
# 2                1
# ...

# %%
df1.drop(columns = 'key', axis = 1, inplace = True)
# Out:
# <ipython-input-160-7d94ad5544a3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop(columns = 'key', axis = 1, inplace = True)

# %%
df1.head()
# Out:
#    fare_amount          pickup_datetime  pickup_longitude  pickup_latitude  \
# 0          7.5  2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1          7.7  2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2         12.9  2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3          5.3  2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4         16.0  2014-08-28 17:47:00 UTC        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count
# 0         -73.999512         40.723217                1
# 1         -73.994710         40.750325                1
# 2         -73.962565         40.772647                1
# 3         -73.965316         40.803349                3
# 4         -73.973082         40.761247                5

# %%
#Extracting only time from pickup_datetime column

df1['pickup_time'] = df1['pickup_datetime'].str.split(' ').str[1]
# Out:
# <ipython-input-162-e03c08081035>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['pickup_time'] = df1['pickup_datetime'].str.split(' ').str[1]

# %%
df1.head()
# Out:
#    fare_amount          pickup_datetime  pickup_longitude  pickup_latitude  \
# 0          7.5  2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1          7.7  2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2         12.9  2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3          5.3  2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4         16.0  2014-08-28 17:47:00 UTC        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count pickup_time
# 0         -73.999512         40.723217                1    19:52:06
# 1         -73.994710         40.750325                1    20:04:56
# 2         -73.962565         40.772647                1    21:45:00
# 3         -73.965316         40.803349                3    08:22:21
# 4         -73.973082         40.761247                5    17:47:00

# %%
df1.head()
# Out:
#    fare_amount          pickup_datetime  pickup_longitude  pickup_latitude  \
# 0          7.5  2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1          7.7  2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2         12.9  2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3          5.3  2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4         16.0  2014-08-28 17:47:00 UTC        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count pickup_time
# 0         -73.999512         40.723217                1    19:52:06
# 1         -73.994710         40.750325                1    20:04:56
# 2         -73.962565         40.772647                1    21:45:00
# 3         -73.965316         40.803349                3    08:22:21
# 4         -73.973082         40.761247                5    17:47:00

# %%
df1['passenger_count'].nunique()
# Out:
# 8

# %%
df1['passenger_count'].unique()
# Out:
# array([  1,   3,   5,   2,   4,   6,   0, 208])

# %%
df1['passenger_count'].value_counts()
# Out:
# 1      138425
# 2       29428
# 5       14009
# 3        8881
# 4        4276
# 6        4271
# 0         708
# 208         1
# Name: passenger_count, dtype: int64

# %%
df1 = df1[df1['passenger_count'] != 208]

# %%
df1['passenger_count'].value_counts()
# Out:
# 1    138425
# 2     29428
# 5     14009
# 3      8881
# 4      4276
# 6      4271
# 0       708
# Name: passenger_count, dtype: int64

# %%
df1.shape
# Out:
# (199998, 8)

# %%
df1.head()
# Out:
#    fare_amount          pickup_datetime  pickup_longitude  pickup_latitude  \
# 0          7.5  2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1          7.7  2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2         12.9  2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3          5.3  2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4         16.0  2014-08-28 17:47:00 UTC        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count pickup_time
# 0         -73.999512         40.723217                1    19:52:06
# 1         -73.994710         40.750325                1    20:04:56
# 2         -73.962565         40.772647                1    21:45:00
# 3         -73.965316         40.803349                3    08:22:21
# 4         -73.973082         40.761247                5    17:47:00

# %%
# Creating Distance column using pickup_longitude, pickup_latitude, dropoff_longitude, dropoff_latitude.
# We will use Haversine formula, to calculate the distance.
# Haversine formula is a commonly used method to calculate the great-circle distance between two points on the Earth's surface given their latitude and longitude.

def haversine_distance(lat1, lon1, lat2, lon2):
    # Radius of the Earth in kilometers
    R = 6371.0

    # Convert latitude and longitude from degrees to radians
    lat1 = np.radians(lat1)
    lon1 = np.radians(lon1)
    lat2 = np.radians(lat2)
    lon2 = np.radians(lon2)

    # Haversine formula
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = np.sin(dlat / 2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2)**2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a))
    distance = R * c

    return distance

# %%
df1['distance_km'] = haversine_distance(df1['pickup_latitude'], df1['pickup_longitude'],
                                        df1['dropoff_latitude'], df1['dropoff_longitude'])
# Out:
# <ipython-input-173-998806c808bc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['distance_km'] = haversine_distance(df1['pickup_latitude'], df1['pickup_longitude'],

# %%
df1.head()
# Out:
#    fare_amount          pickup_datetime  pickup_longitude  pickup_latitude  \
# 0          7.5  2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1          7.7  2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2         12.9  2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3          5.3  2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4         16.0  2014-08-28 17:47:00 UTC        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count pickup_time  \
# 0         -73.999512         40.723217                1    19:52:06
# 1         -73.994710         40.750325                1    20:04:56
# 2         -73.962565         40.772647                1    21:45:00
# 3         -73.965316         40.803349                3    08:22:21
# 4         -73.973082         40.761247                5    17:47:00
#
#    distance_km
# 0     1.683323
# 1     2.457590
# 2     5.036377
# 3     1.661683
# 4     4.475450

# %%
correlation_matrix = df1.corr()

# Creating heatmap check correlation
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
# Out:
# <ipython-input-175-834fd5a8e1dd>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df1.corr()
# <Axes: >

# %%
# Plotting scatter plot between fare_amount vs passenger_count

plt.figure(figsize=(8, 6))
plt.scatter(df1['passenger_count'], df1['fare_amount'], alpha=0.5)
plt.title('Scatter Plot of Fare Amount vs Passenger Count')
plt.xlabel('Passenger Count')
plt.ylabel('Fare Amount')
# Out:
# Text(0, 0.5, 'Fare Amount')

# %%
# Filter rows where 'fare_amount' is between 0 and 220 (inclusive)
df1 = df1[(df1['fare_amount'] >= 0) & (df1['fare_amount'] <= 220)]

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df1['passenger_count'], df1['fare_amount'], alpha=0.5)
plt.title('Scatter Plot of Fare Amount vs Passenger Count')
plt.xlabel('Passenger Count')
plt.ylabel('Fare Amount')
# Out:
# Text(0, 0.5, 'Fare Amount')

# %%
df1.head()
# Out:
#    fare_amount          pickup_datetime  pickup_longitude  pickup_latitude  \
# 0          7.5  2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1          7.7  2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2         12.9  2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3          5.3  2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4         16.0  2014-08-28 17:47:00 UTC        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count pickup_time  \
# 0         -73.999512         40.723217                1    19:52:06
# 1         -73.994710         40.750325                1    20:04:56
# 2         -73.962565         40.772647                1    21:45:00
# 3         -73.965316         40.803349                3    08:22:21
# 4         -73.973082         40.761247                5    17:47:00
#
#    distance_km
# 0     1.683323
# 1     2.457590
# 2     5.036377
# 3     1.661683
# 4     4.475450

# %%
df1.shape
# Out:
# (199976, 9)

# %%
df1['distance_km'].describe()
# Out:
# count    199976.000000
# mean         20.814021
# std         382.498342
# min           0.000000
# 25%           1.215408
# 50%           2.121128
# 75%           3.875358
# max       16409.239135
# Name: distance_km, dtype: float64

# %%
df1.head()
# Out:
#    fare_amount          pickup_datetime  pickup_longitude  pickup_latitude  \
# 0          7.5  2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1          7.7  2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2         12.9  2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3          5.3  2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4         16.0  2014-08-28 17:47:00 UTC        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count pickup_time  \
# 0         -73.999512         40.723217                1    19:52:06
# 1         -73.994710         40.750325                1    20:04:56
# 2         -73.962565         40.772647                1    21:45:00
# 3         -73.965316         40.803349                3    08:22:21
# 4         -73.973082         40.761247                5    17:47:00
#
#    distance_km
# 0     1.683323
# 1     2.457590
# 2     5.036377
# 3     1.661683
# 4     4.475450

# %%
df1['passenger_count'].unique()
# Out:
# array([1, 3, 5, 2, 4, 6, 0])

# %%
# Dropping rows with zero passengers

df1 = df1[df1['passenger_count'] != 0]

# %%
df1['passenger_count'].unique()
# Out:
# array([1, 3, 5, 2, 4, 6])

# %%
df1.shape
# Out:
# (199268, 9)

# %%
df1.head()
# Out:
#    fare_amount          pickup_datetime  pickup_longitude  pickup_latitude  \
# 0          7.5  2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1          7.7  2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2         12.9  2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3          5.3  2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4         16.0  2014-08-28 17:47:00 UTC        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count pickup_time  \
# 0         -73.999512         40.723217                1    19:52:06
# 1         -73.994710         40.750325                1    20:04:56
# 2         -73.962565         40.772647                1    21:45:00
# 3         -73.965316         40.803349                3    08:22:21
# 4         -73.973082         40.761247                5    17:47:00
#
#    distance_km
# 0     1.683323
# 1     2.457590
# 2     5.036377
# 3     1.661683
# 4     4.475450

# %%
# latitude value should be between -90 to +90 and Longitude value should be between -180 to +180.

wrong_lat_log = df1[(df1['pickup_latitude']>90) | (df1['pickup_latitude']<-90)|
                    (df1['dropoff_latitude']>90) | (df1['dropoff_latitude']< -90)|
                    (df1['pickup_longitude']>180) | (df1['pickup_longitude']<-180) |
                    (df1['dropoff_longitude']>180) | (df1['dropoff_longitude']<-180)]

# %%
wrong_lat_log
# Out:
#         fare_amount          pickup_datetime  pickup_longitude  \
# 4949            4.9  2012-04-28 00:58:00 UTC       -748.016667
# 32549          15.7  2012-06-16 10:04:00 UTC        -74.016055
# 48506          33.7  2011-11-05 23:26:00 UTC       -735.200000
# 56617           8.1  2012-03-11 07:24:00 UTC        -73.960828
# 61793           8.5  2012-06-13 05:45:00 UTC        -73.951385
# 75851          15.7  2011-11-05 00:22:00 UTC      -1340.648410
# 91422          16.1  2011-05-18 13:24:00 UTC         57.418457
# 103745         12.9  2011-10-14 19:04:00 UTC       -736.216667
# 139447         13.7  2012-01-20 11:50:00 UTC        -74.011042
# 144253          7.3  2009-08-26 11:55:00 UTC       -768.550000
# 161652          4.1  2010-05-12 12:19:00 UTC       -735.433332
# 199936          4.1  2012-07-21 16:19:00 UTC       -736.400000
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count  \
# ...

# %%
wrong_lat_log.shape
# Out:
# (12, 9)

# %%
index_to_delete = wrong_lat_log.index
index_to_delete
# Out:
# Int64Index([  4949,  32549,  48506,  56617,  61793,  75851,  91422, 103745,
#             139447, 144253, 161652, 199936],
#            dtype='int64')

# %%
df1.drop(index_to_delete,inplace=True)
# Out:
# <ipython-input-194-3d90c94a011c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop(index_to_delete,inplace=True)

# %%
df1.shape
# Out:
# (199256, 9)

# %%
# Checking if there are any zero distance covered in distance_km column
df1[df1['distance_km']==0].shape
# Out:
# (5611, 9)

# %%
# 5611 records have distance travelled during uber ride = 0 as the pickup and dropoff locations are same for these rides.
# Since, we do not have any extra information, we drop these records

index_to_delete_distance = df1[df1['distance_km']==0].index
df1.drop(index_to_delete_distance,inplace=True)
# Out:
# <ipython-input-197-e50324924c8c>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop(index_to_delete_distance,inplace=True)

# %%
df1.shape
# Out:
# (193645, 9)

# %%
# Latitude and Longitude values for pickup and dropoff locations are all zeros which is the location in South Atlantic Ocean

zero_lat_long = df1[(df1['pickup_longitude']==0) | (df1['pickup_latitude']==0) | (df1['dropoff_longitude']==0) | (df1['dropoff_latitude']==0) ]
zero_lat_long
# Out:
#         fare_amount          pickup_datetime  pickup_longitude  \
# 346           15.50  2015-03-05 19:15:07 UTC          0.000000
# 1067          52.00  2014-02-02 22:27:00 UTC        -73.781095
# 1526           2.50  2014-05-12 12:00:15 UTC        -74.001849
# 2547          10.10  2011-09-20 21:08:00 UTC          0.000000
# 3045          15.00  2013-03-26 02:25:17 UTC          0.000000
# ...             ...                      ...               ...
# 196967        57.33  2014-09-17 09:40:30 UTC          0.000000
# 197468         6.90  2011-02-23 19:42:00 UTC          0.000000
# 197863         7.00  2014-11-18 22:10:03 UTC        -73.962190
# 198567        23.50  2013-10-21 01:28:00 UTC        -73.968115
# 198665        20.10  2012-06-26 21:29:00 UTC         -0.116667
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count  \
# 346            0.000000         -73.979805         40.786030                1
# ...

# %%
index_zero_lat_long = df1[(df1['pickup_longitude']==0) | (df1['pickup_latitude']==0) | (df1['dropoff_longitude']==0) | (df1['dropoff_latitude']==0) ].index

df1.drop(index_zero_lat_long,inplace=True)
# Out:
# <ipython-input-200-90897515720c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop(index_zero_lat_long,inplace=True)

# %%
df1.shape
# Out:
# (193270, 9)

# %%
df1.head()
# Out:
#    fare_amount          pickup_datetime  pickup_longitude  pickup_latitude  \
# 0          7.5  2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1          7.7  2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2         12.9  2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3          5.3  2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4         16.0  2014-08-28 17:47:00 UTC        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count pickup_time  \
# 0         -73.999512         40.723217                1    19:52:06
# 1         -73.994710         40.750325                1    20:04:56
# 2         -73.962565         40.772647                1    21:45:00
# 3         -73.965316         40.803349                3    08:22:21
# 4         -73.973082         40.761247                5    17:47:00
#
#    distance_km
# 0     1.683323
# 1     2.457590
# 2     5.036377
# 3     1.661683
# 4     4.475450

# %%
# Creating year, month, day, week_day, period, quarter column from pickup_datetime column

df1['year'] = pd.DatetimeIndex(df1['pickup_datetime']).year
df1['month'] = pd.DatetimeIndex(df1['pickup_datetime']).month_name()
df1['day'] = pd.DatetimeIndex(df1['pickup_datetime']).day
df1['week_day'] = pd.DatetimeIndex(df1['pickup_datetime']).day_name()
df1['period'] = (pd.DatetimeIndex(df1['pickup_datetime']).hour % 24 + 4) // 4
df1['period'].replace({1: 'Late Night',
                      2: 'Early Morning',
                      3: 'Morning',
                      4: 'Noon',
                      5: 'Evening',
                      6: 'Night'}, inplace=True)
df1['Quarter'] = pd.DatetimeIndex(df1['pickup_datetime']).quarter
# Out:
# <ipython-input-203-088fed39a828>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['year'] = pd.DatetimeIndex(df1['pickup_datetime']).year
# <ipython-input-203-088fed39a828>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['month'] = pd.DatetimeIndex(df1['pickup_datetime']).month_name()
# <ipython-input-203-088fed39a828>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df1.head()
# Out:
#    fare_amount          pickup_datetime  pickup_longitude  pickup_latitude  \
# 0          7.5  2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1          7.7  2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2         12.9  2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3          5.3  2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4         16.0  2014-08-28 17:47:00 UTC        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count pickup_time  \
# 0         -73.999512         40.723217                1    19:52:06
# 1         -73.994710         40.750325                1    20:04:56
# 2         -73.962565         40.772647                1    21:45:00
# 3         -73.965316         40.803349                3    08:22:21
# 4         -73.973082         40.761247                5    17:47:00
#
#    distance_km  year   month  day  week_day   period  Quarter
# ...

# %%
# Predicting the fare_amount we need this columns only: 'fare_amount','passenger_count','distance_km','year','month','week_day','period','Quarter'.

df2 = df1[['fare_amount','passenger_count','distance_km','year','month','week_day','period','Quarter']]
df2.head()
# Out:
#    fare_amount  passenger_count  distance_km  year   month  week_day   period  \
# 0          7.5                1     1.683323  2015     May  Thursday  Evening
# 1          7.7                1     2.457590  2009    July    Friday    Night
# 2         12.9                1     5.036377  2009  August    Monday    Night
# 3          5.3                3     1.661683  2009    June    Friday  Morning
# 4         16.0                5     4.475450  2014  August  Thursday  Evening
#
#    Quarter
# 0        2
# 1        3
# 2        3
# 3        2
# 4        3

# %%
df2.shape
# Out:
# (193270, 8)

# %%
for col in ['year','month','Quarter','week_day','period','passenger_count']:
    sns.countplot(data = df2, x = col)
    plt.xticks(rotation=45)
    plt.show()

# %%
df2['period'].unique()
# Out:
# array(['Evening', 'Night', 'Morning', 'Early Morning', 'Noon',
#        'Late Night'], dtype=object)

# %%
df2['period'].replace({'Early Morning' : 1,
                           'Morning' : 2,
                           'Noon' : 3,
                           'Evening' : 4,
                           'Night' : 5,
                           'Late Night' : 6},inplace=True)
# Out:
# <ipython-input-210-abd88071db92>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['period'].replace({'Early Morning' : 1,

# %%
df2['month'].unique()
# Out:
# array(['May', 'July', 'August', 'June', 'October', 'February', 'March',
#        'April', 'September', 'November', 'January', 'December'],
#       dtype=object)

# %%
df2['month'].replace({'January':1, 'February':2, 'March':3, 'April':4,'May':5,'June':6,'July':7,'August':8,
                      'September' :9, 'October':10, 'November':11, 'December':12},inplace=True)
# Out:
# <ipython-input-212-ef518512b94f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['month'].replace({'January':1, 'February':2, 'March':3, 'April':4,'May':5,'June':6,'July':7,'August':8,

# %%
df2['week_day'].unique()
# Out:
# array(['Thursday', 'Friday', 'Monday', 'Sunday', 'Tuesday', 'Saturday',
#        'Wednesday'], dtype=object)

# %%
df2['week_day'].replace({'Monday':1,'Tuesday':2,'Wednesday':3,'Thursday':4,'Friday':5,'Saturday':6,'Sunday':7},inplace=True)
# Out:
# <ipython-input-216-4f1d36d220d3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['week_day'].replace({'Monday':1,'Tuesday':2,'Wednesday':3,'Thursday':4,'Friday':5,'Saturday':6,'Sunday':7},inplace=True)

# %%
df2['year'].unique()
# Out:
# array([2015, 2009, 2014, 2012, 2011, 2010, 2013])

# %%
df2['year'].replace({2009:1,2010:2,2011:3,2012:4,2013:5,2014:6,2015:7},inplace=True)
# Out:
# <ipython-input-218-6375dca7a26b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['year'].replace({2009:1,2010:2,2011:3,2012:4,2013:5,2014:6,2015:7},inplace=True)

# %%
df2.head()
# Out:
#    fare_amount  passenger_count  distance_km  year  month  week_day  period  \
# 0          7.5                1     1.683323     7      5         4       4
# 1          7.7                1     2.457590     1      7         5       5
# 2         12.9                1     5.036377     1      8         1       5
# 3          5.3                3     1.661683     1      6         5       2
# 4         16.0                5     4.475450     6      8         4       4
#
#    Quarter
# 0        2
# 1        3
# 2        3
# 3        2
# 4        3

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 193270 entries, 0 to 199999
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   fare_amount      193270 non-null  float64
#  1   passenger_count  193270 non-null  int64
#  2   distance_km      193270 non-null  float64
#  3   year             193270 non-null  int64
#  4   month            193270 non-null  int64
#  5   week_day         193270 non-null  int64
#  6   period           193270 non-null  int64
#  7   Quarter          193270 non-null  int64
# dtypes: float64(2), int64(6)
# memory usage: 13.3 MB

# %%
plt.scatter(data = df2,x='distance_km',y='fare_amount')

# %%
for feature in ['fare_amount','distance_km']:

    q1 = df2[feature].quantile(0.25)
    q3 = df2[feature].quantile(0.75)
    iqr = q3-q1
    upper_whisker = q3+1.5*iqr
    lower_whisker = q1-1.5*iqr
    print(str.upper(feature))
    print('Upper Whisker',upper_whisker)
    print('Lower Whisker',lower_whisker)
    print('************************************')
# Out:
# FARE_AMOUNT
# Upper Whisker 22.25
# Lower Whisker -3.75
# ************************************
# DISTANCE_KM
# Upper Whisker 7.9375723500773745
# Lower Whisker -2.713752593537169
# ************************************

# %%
df2[['fare_amount']].boxplot(vert=0)
# Out:
# <Axes: >

# %%
for feature in ['fare_amount','distance_km']:
    q1 = df2[feature].quantile(0.25)
    q3 = df2[feature].quantile(0.75)
    iqr = q3-q1
    upper_whisker = q3+1.5*iqr
    lower_whisker = q1-1.5*iqr
    df2[feature]=np.where(df2[feature]<lower_whisker,lower_whisker,df2[feature])
    df2[feature]=np.where(df2[feature]>upper_whisker,upper_whisker,df2[feature])
# Out:
# <ipython-input-226-2c8c4fbca301>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[feature]=np.where(df2[feature]<lower_whisker,lower_whisker,df2[feature])
# <ipython-input-226-2c8c4fbca301>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[feature]=np.where(df2[feature]>upper_whisker,upper_whisker,df2[feature])
# <ipython-input-226-2c8c4fbca301>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df2[['fare_amount','distance_km']].boxplot(vert=0)
# Out:
# <Axes: >

# %%
# Checking correlation in df2

correlation = df2.corr()
plt.figure(figsize=(10,10))
sns.heatmap(correlation,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### The heatmap shows that the target column i.e. fare_amount and distance_km have a very strong correlation.

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
# Scaling the df2

scaler = MinMaxScaler()
df2_scaled = scaler.fit_transform(df2)
df2_scaled = pd.DataFrame(df2_scaled,columns=df2.columns)
df2_scaled
# Out:
#         fare_amount  passenger_count  distance_km      year     month  \
# 0          0.337079              0.0     0.212062  1.000000  0.363636
# 1          0.346067              0.0     0.309607  0.000000  0.545455
# 2          0.579775              0.0     0.634495  0.000000  0.636364
# 3          0.238202              0.4     0.209336  0.000000  0.454545
# 4          0.719101              0.8     0.563826  0.833333  0.636364
# ...             ...              ...          ...       ...       ...
# 193265     0.134831              0.0     0.014126  0.500000  0.818182
# 193266     0.337079              0.0     0.236217  0.833333  0.181818
# 193267     1.000000              0.2     1.000000  0.000000  0.454545
# 193268     0.651685              0.0     0.445938  1.000000  0.363636
# 193269     0.633708              0.0     0.682546  0.166667  0.363636
#
#         week_day  period   Quarter
# 0       0.500000     0.6  0.333333
# 1       0.666667     0.8  0.666667
# ...

# %%
# Calculating VIF Score to check the amount of inflation in the variances of the regression coefficients due to multicollinearity

# %%
from statsmodels.formula.api import ols

# %%
f_passenger_count = 'passenger_count~distance_km+year+month+week_day+period+Quarter'
m_passenger_count = ols(formula=f_passenger_count,data=df2_scaled).fit()
rsq_passenger_count = m_passenger_count.rsquared
vif_passenger_count = round(1/(1-rsq_passenger_count),2)

f_distance_km = 'distance_km~passenger_count+year+month+week_day+period+Quarter'
m_distance_km = ols(formula=f_distance_km,data=df2_scaled).fit()
rsq_distance_km = m_distance_km.rsquared
vif_distance_km = round(1/(1-rsq_distance_km),2)

f_year = 'year~passenger_count+distance_km+month+week_day+period+Quarter'
m_year = ols(formula=f_year,data=df2_scaled).fit()
rsq_year = m_year.rsquared
vif_year = round(1/(1-rsq_year),2)

f_month = 'month~passenger_count+distance_km+year+week_day+period+Quarter'
m_month = ols(formula=f_month,data=df2_scaled).fit()
rsq_month = m_month.rsquared
vif_month = round(1/(1-rsq_month),2)

f_week_day = 'week_day~passenger_count+distance_km+year+month+period+Quarter'
m_week_day = ols(formula=f_week_day,data=df2_scaled).fit()
rsq_week_day = m_week_day.rsquared
vif_week_day = round(1/(1-rsq_week_day),2)

f_period = 'period~passenger_count+distance_km+year+month+week_day+Quarter'
m_period = ols(formula=f_period,data=df2_scaled).fit()
rsq_period = m_period.rsquared
vif_period = round(1/(1-rsq_period),2)

f_Quarter = 'Quarter~passenger_count+distance_km+year+month+week_day+period'
m_Quarter = ols(formula=f_Quarter,data=df2_scaled).fit()
rsq_Quarter = m_Quarter.rsquared
vif_Quarter = round(1/(1-rsq_Quarter),2)

# %%
vif_dic = {'feature':['passenger_count', 'distance_km', 'year', 'month',
       'week_day', 'period', 'Quarter'], 'VIF':[vif_passenger_count,vif_distance_km,vif_year,vif_month,vif_week_day,vif_period,vif_Quarter]}
pd.DataFrame(data=vif_dic)
# Out:
#            feature    VIF
# 0  passenger_count   1.00
# 1      distance_km   1.00
# 2             year   1.01
# 3            month  17.54
# 4         week_day   1.02
# 5           period   1.02
# 6          Quarter  17.55

# %%
# Here month and quarter columns have VIF score more than 5, it shows multi collinearity is present. We can drop the Quarter column

f_passenger_count = 'passenger_count~distance_km+year+month+week_day+period'
m_passenger_count = ols(formula=f_passenger_count,data=df2_scaled).fit()
rsq_passenger_count = m_passenger_count.rsquared
vif_passenger_count = round(1/(1-rsq_passenger_count),2)

f_distance_km = 'distance_km~passenger_count+year+month+week_day+period'
m_distance_km = ols(formula=f_distance_km,data=df2_scaled).fit()
rsq_distance_km = m_distance_km.rsquared
vif_distance_km = round(1/(1-rsq_distance_km),2)

f_year = 'year~passenger_count+distance_km+month+week_day+period'
m_year = ols(formula=f_year,data=df2_scaled).fit()
rsq_year = m_year.rsquared
vif_year = round(1/(1-rsq_year),2)

f_month = 'month~passenger_count+distance_km+year+week_day+period'
m_month = ols(formula=f_month,data=df2_scaled).fit()
rsq_month = m_month.rsquared
vif_month = round(1/(1-rsq_month),2)

f_week_day = 'week_day~passenger_count+distance_km+year+month+period'
m_week_day = ols(formula=f_week_day,data=df2_scaled).fit()
rsq_week_day = m_week_day.rsquared
vif_week_day = round(1/(1-rsq_week_day),2)

f_period = 'period~passenger_count+distance_km+year+month+week_day'
m_period = ols(formula=f_period,data=df2_scaled).fit()
rsq_period = m_period.rsquared
vif_period = round(1/(1-rsq_period),2)

vif_dic = {'feature':['passenger_count', 'distance_km', 'year', 'month',
       'week_day', 'period'], 'VIF':[vif_passenger_count,vif_distance_km,vif_year,vif_month,vif_week_day,vif_period]}
pd.DataFrame(data=vif_dic)
# Out:
#            feature   VIF
# 0  passenger_count  1.00
# 1      distance_km  1.00
# 2             year  1.01
# 3            month  1.01
# 4         week_day  1.02
# 5           period  1.02

# %%
df2_scaled.head()
# Out:
#    fare_amount  passenger_count  distance_km      year     month  week_day  \
# 0     0.337079              0.0     0.212062  1.000000  0.363636  0.500000
# 1     0.346067              0.0     0.309607  0.000000  0.545455  0.666667
# 2     0.579775              0.0     0.634495  0.000000  0.636364  0.000000
# 3     0.238202              0.4     0.209336  0.000000  0.454545  0.666667
# 4     0.719101              0.8     0.563826  0.833333  0.636364  0.500000
#
#    period   Quarter
# 0     0.6  0.333333
# 1     0.8  0.666667
# 2     0.8  0.666667
# 3     0.2  0.333333
# 4     0.6  0.666667

# %% [markdown]
# ### Train-Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X = df2_scaled.drop(['Quarter'],axis=1)
y = df2_scaled['fare_amount']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.30,random_state=1)

# %%
X_train.shape
# Out:
# (135289, 7)

# %%
X_test.shape
# Out:
# (57981, 7)

# %% [markdown]
# ### Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error


model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse}")
# Out:
# Mean Squared Error: 1.5181826964932683e-31

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

RF_model = RandomForestRegressor(random_state=42)
RF_model.fit(X_train, y_train)

y_pred = RF_model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error (Random Forest): {mse}")
# Out:
# Mean Squared Error (Random Forest): 2.659554698166808e-09

# %% [markdown]
# ### Saving the random forest model

# %%
import joblib

# Assuming 'model' is your trained Random Forest model
model_filename = 'uber_fare_price.pkl'

# Save the model to a .pkl file
joblib.dump(RF_model, model_filename)
# Out:
# ['uber_fare_price.pkl']
